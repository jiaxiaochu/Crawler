# %%
import numpy as np
import seaborn as sns
# 从标准正态分布中随机地抽取1000个数
data = np.random.normal(size=1000) 
sns.set(style='darkgrid')
sns.distplot(data,kde=True)

# %%
sns.kdeplot(data1, data2, shade = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15c183d9b845> in <module>
# ----> 1 sns.kdeplot(data1, data2, shade = False)
#
# NameError: name 'data1' is not defined

# %%
import numpy as np
import seaborn as sns
data = np.random.normal(size=1000) 
sns.set(style='darkgrid')
sns.kdeplot(data, shade = True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 创建dataframe: df
df = pd.DataFrame({'x': np.random.normal(size=500),
                   'y': np.random.normal(size=500)})
# 绘制双变量散点图
sns.jointplot(x='x', y='y', data=df,kind='reg')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.DataFrame({'x': np.random.randn(500),
                   'y': np.random.randn(500)})
sns.jointplot(x='x', y='y', data=df, kind='kde')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/Users/jiazhixiang/Desktop/11111/数据分析课/data/iris.csv')
sns.pairplot(data,hue='species')
plt.show()

# %%
# 导入需要用到的库
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 读取数据
data = pd.read_csv('/Users/jiazhixiang/Desktop/11111/数据分析课/data/tips.csv')
# 查看数据
data.head()

# 绘制用餐人数的概率分布图
# 取出用餐人数
size = data['size']
sns.set(style='darkgrid')
sns.distplot(size,kde=True)

# 绘制出用餐人数与小费的散点图
# 取出用餐人数与小费的数据
data = data[['size','tip']]
# 参数x_jitter，这个参数可以设置size值的偏离范围，这里size代表用餐人数，那么我们设置的x_jitter应该在0-1之间，我们设置为0.3,散点图显得更易观察
sns.jointplot(x='size', y='tip', data=data,kind='reg',x_jitter=0.3)

# %%
# 导入需要用到的库
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 读取数据
data = pd.read_csv('/Users/jiazhixiang/Desktop/11111/数据分析课/data/tips.csv')
# 绘制出每两列变量之间的关系
sns.pairplot(data)

# 不同性别的消费数据有没有明显的差别
sns.pairplot(data,hue='sex')
# 绘制消费总额与小费两个变量的关系分布图
sns.pairplot(data,vars=['total_bill', 'tip'],kind='reg', diag_kind='kde')
plt.show()

# %%
from matplotlib import pyplot as plt
import random

# %%
# 直线1
plt.plot([0,1],[0,1])
plt.show()

# %%
# 直线2
plt.figure(figsize=(10,5))
plt.plot([0,1],[0,1])
plt.show()

# %%
# 折线图绘制与显示
# %matplotlib inline
plt.figure(figsize=(5,5))
plt.plot([0,1,2,3,4,5],[3,4,5,2,1,0])
plt.show()

# %% [markdown]
# ## 散点图绘制与显示

# %%
plt.scatter([1,2,3,4],[5,6,7,8])
plt.show()

# %% [markdown]
# ## 修改图形大小与图片保存

# %%
#设置图片大小
plt.figure(figsize=(), dpi=)
    figsize:指定图的长宽
    dpi:图像的清晰度
    返回fig对象

#保存为图片
plt.savefig(path)

# %%
plt.figure(figsize=(20,8),dpi=80)
plt.savefig("matplotlib-plot.png")

# %%
# %matplotlib inline  # 在jupyter notebook中启用对matplotlib的支持

# %%
from matplotlib import pyplot as plt
import random

# %%
x = range(3,61)
y = [random.randint(10,20)for i in x]
plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y)
plt.show();
